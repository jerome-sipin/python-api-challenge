# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Import dependencies, API key
import matplotlib.pyplot as plt
import requests
from scipy import stats
import pandas as pd
import numpy as np
from citipy import citipy
from api_keys import weather_api_key

# API url config
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# %% [markdown]
# ## Generate Cities List

# %%
# Create blank list of longitudes, latitudes, and cities.
lat = []
lng = []
cities = []

# Populate lat and lng lists with appropriate, randomly generated values
# 1500 values are generated to guarantee a sample size of 500+ cities
# -90 to 90 for lat, -180 to 180 for lng
lat = np.random.uniform(low=-90.000, high=90.000, size=1500)
lng = np.random.uniform(low=-180.000, high=180.000, size=1500)

# Find cities using lat and lng generated above
for x in range(1500):
    city = citipy.nearest_city(lat[x], lng[x]).city_name
    
    # Only append cities that are not already in cities list
    if city not in cities:
        cities.append(city)

# Print length of cities list to confirm that it has over 500 cities
len(cities)
# Out:
# 609

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Create city query url template
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# Create blank list for required data
weather_data = []

# Create count variable to keep track of how many iterations the loop
# has been through
i = 0

# Loop through all cities and populate above list with information for each 
# city
for city in cities:
    i += 1
    city_data = requests.get(query_url + city).json()
    
    try:
        # Get required data points
        lat = city_data["coord"]["lat"]
        lng = city_data["coord"]["lon"]
        maxtemp = city_data["main"]["temp_max"]
        humidity = city_data["main"]["humidity"]
        cloudiness = city_data["clouds"]["all"]
        wind_speed = city_data["wind"]["speed"]
        country = city_data["sys"]["country"]
        date = city_data["dt"]
        
        # Append data to previously created weather_data list
        weather_data.append([city, lat, lng, maxtemp, humidity, cloudiness, wind_speed, country, date])
        
        # Confirm that city weather data has been appended to list
        print(f"Finding city {i} | {city}")
        
    except:
        print("City not found.")
# Out:
# Finding city 1 | rikitea
# Finding city 2 | norman wells
# Finding city 3 | atuona
# Finding city 4 | pitkyaranta
# Finding city 5 | mataura
# Finding city 6 | upernavik
# Finding city 7 | ushuaia
# Finding city 8 | pisco
# Finding city 9 | port alfred
# Finding city 10 | choix
# Finding city 11 | hobart
# Finding city 12 | komsomolskiy
# Finding city 13 | albany
# Finding city 14 | butaritari
# Finding city 15 | hasaki
# Finding city 16 | placido de castro
# Finding city 17 | mayo
# Finding city 18 | dingle
# Finding city 19 | kapaa
# Finding city 20 | vila franca do campo
# Finding city 21 | isangel
# Finding city 22 | prainha
# Finding city 23 | cabo san lucas
# Finding city 24 | tessalit
# Finding city 25 | pacific grove
# Finding city 26 | sabana grande de boya
# Finding city 27 | harper
# Finding city 28 | cape town
# Finding city 29 | busselton
# Finding city 30 | korla
# Finding city 31 | port lincoln
# Finding city 32 | tuatapere
# Finding city 33 | dikson
# Finding city 34 | quatre cocos
# Finding city 35 | bethel
# City not found.
# Finding city 37 | kulhudhuffushi
# Finding city 38 | ukiah
# Finding city 39 | lakes entrance
# Finding city 40 | srednekolymsk
# Finding city 41 | fort nelson
# Finding city 42 | uruguaiana
# Finding city 43 | kirakira
# Finding city 44 | avarua
# Finding city 45 | hithadhoo
# Finding city 46 | calama
# Finding city 47 | carnarvon
# Finding city 48 | narsaq
# Finding city 49 | palana
# Finding city 50 | bubaque
# City not found.
# Finding city 52 | willemstad
# Finding city 53 | kalaleh
# Finding city 54 | yellowknife
# Finding city 55 | jamestown
# Finding city 56 | fairbanks
# Finding city 57 | barrow
# Finding city 58 | axim
# Finding city 59 | san cristobal
# Finding city 60 | chihuahua
# City not found.
# Finding city 62 | rancho veloz
# Finding city 63 | nome
# Finding city 64 | hilo
# Finding city 65 | arraial do cabo
# Finding city 66 | luanda
# City not found.
# Finding city 68 | punta arenas
# Finding city 69 | wajir
# Finding city 70 | hermanus
# Finding city 71 | cidreira
# Finding city 72 | mount isa
# Finding city 73 | yangambi
# Finding city 74 | mosquera
# Finding city 75 | tupik
# Finding city 76 | deputatskiy
# Finding city 77 | castanos
# Finding city 78 | kavieng
# Finding city 79 | nanning
# Finding city 80 | mahebourg
# Finding city 81 | kattivakkam
# Finding city 82 | chuy
# Finding city 83 | khatanga
# Finding city 84 | mudgee
# Finding city 85 | suez
# Finding city 86 | waddan
# Finding city 87 | ulladulla
# Finding city 88 | bredasdorp
# Finding city 89 | praia da vitoria
# Finding city 90 | puerto ayora
# Finding city 91 | klaksvik
# City not found.
# Finding city 93 | sydney
# City not found.
# Finding city 95 | airai
# Finding city 96 | tiksi
# Finding city 97 | mae sai
# Finding city 98 | batagay-alyta
# Finding city 99 | maracacume
# Finding city 100 | cuamba
# Finding city 101 | maracaju
# Finding city 102 | severo-kurilsk
# Finding city 103 | viedma
# Finding city 104 | grindavik
# Finding city 105 | eureka
# Finding city 106 | hervey bay
# City not found.
# Finding city 108 | thompson
# Finding city 109 | san pedro
# City not found.
# Finding city 111 | broni
# Finding city 112 | suntar
# Finding city 113 | pevek
# Finding city 114 | talnakh
# Finding city 115 | mukhen
# Finding city 116 | teya
# Finding city 117 | abnub
# Finding city 118 | pipri
# Finding city 119 | alofi
# Finding city 120 | tuktoyaktuk
# Finding city 121 | fort collins
# Finding city 122 | kahului
# Finding city 123 | katobu
# Finding city 124 | portland
# Finding city 125 | faanui
# City not found.
# Finding city 127 | ostrovnoy
# Finding city 128 | sao filipe
# Finding city 129 | rawson
# Finding city 130 | new norfolk
# Finding city 131 | luderitz
# City not found.
# Finding city 133 | ponta do sol
# Finding city 134 | haines junction
# Finding city 135 | port elizabeth
# Finding city 136 | alto araguaia
# Finding city 137 | iqaluit
# Finding city 138 | tilichiki
# Finding city 139 | henties bay
# City not found.
# Finding city 141 | ballina
# Finding city 142 | matagami
# Finding city 143 | shelburne
# Finding city 144 | yar-sale
# Finding city 145 | bluff
# Finding city 146 | college
# Finding city 147 | esil
# Finding city 148 | antofagasta
# Finding city 149 | tabou
# Finding city 150 | souillac
# Finding city 151 | oksfjord
# Finding city 152 | takayama
# Finding city 153 | kipushi
# Finding city 154 | houston
# Finding city 155 | jalu
# City not found.
# Finding city 157 | marsh harbour
# Finding city 158 | georgetown
# Finding city 159 | saskylakh
# Finding city 160 | sterling
# Finding city 161 | may pen
# City not found.
# Finding city 163 | masvingo
# Finding city 164 | sabang
# Finding city 165 | hami
# Finding city 166 | bilma
# City not found.
# City not found.
# Finding city 169 | alugan
# Finding city 170 | geraldton
# Finding city 171 | usinsk
# Finding city 172 | torbay
# Finding city 173 | itoman
# Finding city 174 | north bend
# Finding city 175 | bonavista
# Finding city 176 | nikolskoye
# Finding city 177 | ambilobe
# Finding city 178 | bambous virieux
# Finding city 179 | northam
# Finding city 180 | alvaraes
# Finding city 181 | northampton
# Finding city 182 | sao joao da barra
# Finding city 183 | mackay
# Finding city 184 | alekseyevskoye
# Finding city 185 | wundanyi
# Finding city 186 | vinh
# Finding city 187 | qaanaaq
# Finding city 188 | ixtapa
# Finding city 189 | shambu
# Finding city 190 | ambon
# Finding city 191 | codrington
# Finding city 192 | ituango
# Finding city 193 | vaini
# Finding city 194 | teofilo otoni
# Finding city 195 | kieta
# Finding city 196 | kosum phisai
# Finding city 197 | kaitangata
# Finding city 198 | kalmar
# City not found.
# Finding city 200 | san patricio
# Finding city 201 | mitsamiouli
# Finding city 202 | mbabane
# Finding city 203 | spassk
# Finding city 204 | searcy
# Finding city 205 | astoria
# Finding city 206 | sargatskoye
# City not found.
# Finding city 208 | nevsehir
# Finding city 209 | hay river
# Finding city 210 | edendale
# City not found.
# Finding city 212 | dhidhdhoo
# Finding city 213 | znamenskoye
# Finding city 214 | naze
# Finding city 215 | radovis
# Finding city 216 | mar del plata
# Finding city 217 | pontes e lacerda
# Finding city 218 | alta floresta
# Finding city 219 | sur
# Finding city 220 | saint-philippe
# Finding city 221 | norwich
# Finding city 222 | vertientes
# City not found.
# Finding city 224 | blagoyevo
# Finding city 225 | dosso
# Finding city 226 | newport
# Finding city 227 | iralaya
# Finding city 228 | vanavara
# City not found.
# Finding city 230 | rochegda
# Finding city 231 | sisimiut
# Finding city 232 | kiama
# Finding city 233 | boyolangu
# Finding city 234 | coquimbo
# Finding city 235 | kismayo
# Finding city 236 | margherita
# Finding city 237 | cap malheureux
# Finding city 238 | helong
# Finding city 239 | lebu
# Finding city 240 | keuruu
# Finding city 241 | pampa
# Finding city 242 | banda aceh
# Finding city 243 | mount gambier
# Finding city 244 | saint anthony
# Finding city 245 | ternova
# Finding city 246 | westport
# Finding city 247 | tura
# City not found.
# Finding city 249 | tasiilaq
# Finding city 250 | bulawayo
# Finding city 251 | yambio
# Finding city 252 | summerside
# Finding city 253 | kruisfontein
# Finding city 254 | prince rupert
# Finding city 255 | kodiak
# Finding city 256 | berlevag
# Finding city 257 | chokurdakh
# Finding city 258 | east london
# Finding city 259 | karaton
# Finding city 260 | castro
# Finding city 261 | touros
# Finding city 262 | eha amufu
# Finding city 263 | guanare
# City not found.
# Finding city 265 | pathein
# Finding city 266 | velizh
# Finding city 267 | victoria
# Finding city 268 | madang
# Finding city 269 | la ronge
# Finding city 270 | murmino
# Finding city 271 | yerbogachen
# Finding city 272 | dwarka
# Finding city 273 | vostok
# Finding city 274 | coffeyville
# Finding city 275 | isfana
# Finding city 276 | beringovskiy
# Finding city 277 | demba
# Finding city 278 | husavik
# Finding city 279 | lorengau
# Finding city 280 | leningradskiy
# Finding city 281 | san policarpo
# Finding city 282 | cabedelo
# Finding city 283 | lata
# Finding city 284 | cayenne
# Finding city 285 | mega
# Finding city 286 | jacareacanga
# Finding city 287 | divnomorskoye
# Finding city 288 | fortuna
# Finding city 289 | constitucion
# Finding city 290 | dunedin
# Finding city 291 | guerrero negro
# Finding city 292 | ribeira grande
# Finding city 293 | oranjemund
# Finding city 294 | monrovia
# Finding city 295 | acton
# City not found.
# City not found.
# Finding city 298 | cherskiy
# Finding city 299 | pitimbu
# City not found.
# Finding city 301 | alice springs
# Finding city 302 | tateyama
# Finding city 303 | saint george
# Finding city 304 | tabas
# Finding city 305 | arlit
# Finding city 306 | waipawa
# Finding city 307 | chicama
# Finding city 308 | nicoya
# City not found.
# Finding city 310 | aswan
# Finding city 311 | yulara
# Finding city 312 | tchibanga
# Finding city 313 | anloga
# Finding city 314 | nadym
# Finding city 315 | hamilton
# City not found.
# Finding city 317 | fougeres
# Finding city 318 | vila do maio
# Finding city 319 | washougal
# Finding city 320 | saldanha
# Finding city 321 | dyurtyuli
# Finding city 322 | kholodnyy
# Finding city 323 | jumla
# Finding city 324 | qandala
# Finding city 325 | beaupre
# Finding city 326 | flinders
# Finding city 327 | bonthe
# Finding city 328 | ambunti
# Finding city 329 | dabola
# Finding city 330 | abonnema
# Finding city 331 | norrtalje
# Finding city 332 | krutinka
# Finding city 333 | aurad
# Finding city 334 | marshall
# Finding city 335 | mombetsu
# Finding city 336 | umm kaddadah
# Finding city 337 | bathsheba
# Finding city 338 | vardo
# Finding city 339 | middle island
# Finding city 340 | zhezkazgan
# Finding city 341 | teguldet
# Finding city 342 | ahipara
# Finding city 343 | shar
# Finding city 344 | laguna
# Finding city 345 | rorvik
# Finding city 346 | rantepao
# Finding city 347 | port-gentil
# City not found.
# Finding city 349 | jacqueville
# Finding city 350 | cervo
# Finding city 351 | mariinsk
# Finding city 352 | muisne
# City not found.
# Finding city 354 | salinas
# Finding city 355 | osoyoos
# Finding city 356 | fernandez
# Finding city 357 | luohe
# Finding city 358 | lincoln
# City not found.
# Finding city 360 | janauba
# Finding city 361 | labuhan
# Finding city 362 | maceio
# Finding city 363 | ust-nera
# Finding city 364 | tulagi
# Finding city 365 | havre-saint-pierre
# City not found.
# Finding city 367 | neyshabur
# Finding city 368 | ternate
# Finding city 369 | buala
# City not found.
# Finding city 371 | berkakit
# Finding city 372 | pangnirtung
# Finding city 373 | bengkulu
# Finding city 374 | nantucket
# Finding city 375 | sobolevo
# Finding city 376 | dire
# Finding city 377 | namanyere
# Finding city 378 | rancho palos verdes
# City not found.
# Finding city 380 | clyde river
# Finding city 381 | sojat
# Finding city 382 | innisfail
# Finding city 383 | pimenta bueno
# Finding city 384 | itarema
# Finding city 385 | lubumbashi
# Finding city 386 | katihar
# City not found.
# City not found.
# Finding city 389 | ust-kishert
# Finding city 390 | wonthaggi
# Finding city 391 | nabire
# Finding city 392 | khandbari
# Finding city 393 | coihaique
# Finding city 394 | russkaya polyana
# Finding city 395 | mont-dore
# Finding city 396 | ardakan
# Finding city 397 | caravelas
# Finding city 398 | aquiraz
# City not found.
# Finding city 400 | chanika
# Finding city 401 | balabac
# Finding city 402 | venustiano carranza
# City not found.
# Finding city 404 | polyarnyy
# Finding city 405 | amapa
# Finding city 406 | sinnamary
# Finding city 407 | ilulissat
# Finding city 408 | goderich
# Finding city 409 | taoudenni
# Finding city 410 | cassilandia
# Finding city 411 | zhuhai
# Finding city 412 | maragogi
# Finding city 413 | seymchan
# Finding city 414 | mindelo
# Finding city 415 | gogrial
# Finding city 416 | kamaishi
# Finding city 417 | canas
# Finding city 418 | hvide sande
# Finding city 419 | uray
# Finding city 420 | port augusta
# Finding city 421 | jork
# Finding city 422 | poum
# Finding city 423 | orzinuovi
# Finding city 424 | lompoc
# Finding city 425 | batouri
# Finding city 426 | north platte
# Finding city 427 | okha
# Finding city 428 | ozimek
# Finding city 429 | koindu
# Finding city 430 | evensk
# Finding city 431 | pendencias
# Finding city 432 | salinopolis
# Finding city 433 | kiunga
# Finding city 434 | port hedland
# Finding city 435 | yuli
# Finding city 436 | shimoda
# Finding city 437 | boralday
# Finding city 438 | mayahi
# Finding city 439 | bucerias
# Finding city 440 | puerto penasco
# Finding city 441 | makakilo city
# Finding city 442 | rocha
# Finding city 443 | punta
# Finding city 444 | cam ranh
# Finding city 445 | krasnoselkup
# Finding city 446 | ahuimanu
# Finding city 447 | aligarh
# Finding city 448 | auki
# Finding city 449 | namatanai
# Finding city 450 | haicheng
# Finding city 451 | ranong
# City not found.
# Finding city 453 | longyearbyen
# Finding city 454 | christchurch
# Finding city 455 | walvis bay
# City not found.
# Finding city 457 | melo
# Finding city 458 | umba
# Finding city 459 | hambantota
# Finding city 460 | yeppoon
# Finding city 461 | san andres
# Finding city 462 | kapuskasing
# Finding city 463 | lazaro cardenas
# Finding city 464 | ordynskoye
# Finding city 465 | verkhniye kigi
# Finding city 466 | lagoa
# Finding city 467 | plouzane
# Finding city 468 | jaguaquara
# Finding city 469 | magadan
# Finding city 470 | aripuana
# Finding city 471 | qixingtai
# Finding city 472 | killybegs
# Finding city 473 | uaua
# Finding city 474 | dicabisagan
# Finding city 475 | namibe
# Finding city 476 | karratha
# Finding city 477 | tahta
# Finding city 478 | itanagar
# Finding city 479 | mafeteng
# Finding city 480 | toccoa
# Finding city 481 | dongsheng
# Finding city 482 | troitsko-pechorsk
# Finding city 483 | port alberni
# Finding city 484 | alyangula
# Finding city 485 | aksu
# Finding city 486 | keffi
# Finding city 487 | alice town
# Finding city 488 | ossora
# Finding city 489 | nemuro
# Finding city 490 | samarai
# Finding city 491 | preobrazheniye
# City not found.
# Finding city 493 | shache
# Finding city 494 | upington
# Finding city 495 | casper
# Finding city 496 | guarapari
# City not found.
# Finding city 498 | boende
# Finding city 499 | chitral
# Finding city 500 | poya
# Finding city 501 | riyadh
# Finding city 502 | lamu
# Finding city 503 | katsuura
# Finding city 504 | bereda
# City not found.
# Finding city 506 | innoshima
# Finding city 507 | nyurba
# Finding city 508 | gigmoto
# City not found.
# City not found.
# Finding city 511 | sao miguel do araguaia
# Finding city 512 | vila velha
# Finding city 513 | kuvshinovo
# Finding city 514 | santa catarina de tepehuanes
# Finding city 515 | gat
# Finding city 516 | quebo
# Finding city 517 | limerick
# Finding city 518 | meadow lake
# Finding city 519 | tyulgan
# Finding city 520 | sorland
# Finding city 521 | buin
# Finding city 522 | dengzhou
# Finding city 523 | iskateley
# Finding city 524 | lavrentiya
# Finding city 525 | kavaratti
# Finding city 526 | broome
# Finding city 527 | yumen
# Finding city 528 | manokwari
# Finding city 529 | kannad
# Finding city 530 | progreso
# Finding city 531 | marfino
# Finding city 532 | zaragoza
# Finding city 533 | mayna
# Finding city 534 | marawi
# City not found.
# Finding city 536 | kilindoni
# Finding city 537 | lashio
# Finding city 538 | taraz
# Finding city 539 | rockland
# Finding city 540 | kavos
# Finding city 541 | kalmunai
# City not found.
# Finding city 543 | cockburn town
# Finding city 544 | song phi nong
# Finding city 545 | kabanjahe
# Finding city 546 | lebanon
# Finding city 547 | taltal
# Finding city 548 | lokosovo
# Finding city 549 | nyuksenitsa
# Finding city 550 | baherden
# Finding city 551 | silver city
# Finding city 552 | sovetskiy
# Finding city 553 | nizhniy kuranakh
# Finding city 554 | rio grande
# Finding city 555 | ryazan
# Finding city 556 | sayyan
# Finding city 557 | trelew
# Finding city 558 | nioro
# Finding city 559 | barranca
# Finding city 560 | hengyang
# Finding city 561 | aguimes
# Finding city 562 | weinan
# Finding city 563 | castlemaine
# Finding city 564 | wahiawa
# Finding city 565 | riachao das neves
# City not found.
# Finding city 567 | kysyl-syr
# Finding city 568 | encruzilhada do sul
# Finding city 569 | verkhoyansk
# Finding city 570 | matara
# City not found.
# Finding city 572 | diego de almagro
# Finding city 573 | marienburg
# Finding city 574 | esperance
# Finding city 575 | te anau
# Finding city 576 | bani walid
# Finding city 577 | teacapan
# Finding city 578 | mezen
# Finding city 579 | constantine
# City not found.
# City not found.
# Finding city 582 | urumqi
# Finding city 583 | finschhafen
# Finding city 584 | ulaanbaatar
# Finding city 585 | dong hoi
# Finding city 586 | puerto escondido
# Finding city 587 | lasa
# Finding city 588 | hualmay
# Finding city 589 | cotacachi
# Finding city 590 | zhigansk
# Finding city 591 | lensk
# Finding city 592 | sampit
# City not found.
# Finding city 594 | kosel
# Finding city 595 | domoni
# Finding city 596 | ardahan
# Finding city 597 | vao
# Finding city 598 | saint-louis
# Finding city 599 | itaituba
# Finding city 600 | harrisonville
# Finding city 601 | thinadhoo
# Finding city 602 | karaman
# Finding city 603 | arman
# Finding city 604 | balakhninskiy
# Finding city 605 | katakwi
# City not found.
# Finding city 607 | jizan
# Finding city 608 | sainte-luce
# Finding city 609 | dauphin

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create dataframe
city_data_df = pd.DataFrame(weather_data, columns=["City", "Latitude", "Longitude", "Max. Temp (F)", "Humidity (%)", 
                                                   "Cloudiness (%)", "Wind Speed (MPH)", "Country", "Date"])

# Display dataframe
city_data_df.head()
# Out:
#            City  Latitude  Longitude  Max. Temp (F)  Humidity (%)  \
# 0       rikitea  -23.1203  -134.9692          73.54            74
# 1  norman wells   65.2820  -126.8329          60.84            63
# 2        atuona   -9.8000  -139.0333          77.52            70
# 3   pitkyaranta   61.5734    31.4792          63.52            81
# 4       mataura  -46.1927   168.8643          42.48            98
#
#    Cloudiness (%)  Wind Speed (MPH) Country        Date
# 0              36             17.83      PF  1627323638
# 1              75             11.50      CA  1627323638
# 2              55             25.08      PF  1627323638
# 3              55              3.31      RU  1627323639
# 4              91              2.95      NZ  1627323114

# %%
# Creates "output" folder, converts df to csv, and places new csv in 
# output folder
city_data_df.to_csv("Output/city_weather_data.csv")

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
city_data_df[["Latitude", "Longitude", "Max. Temp (F)", "Humidity (%)", 
              "Cloudiness (%)", "Wind Speed (MPH)", "Country", "Date"]].describe()

# Df shows no cities with humidity over 100%.
# Out:
#          Latitude   Longitude  Max. Temp (F)  Humidity (%)  Cloudiness (%)  \
# count  557.000000  557.000000     557.000000    557.000000      557.000000
# mean    19.299907   21.486599      71.628187     68.052065       54.707361
# std     33.035903   91.405856      14.810120     21.598090       37.013980
# min    -54.800000 -175.200000      35.620000      5.000000        0.000000
# 25%     -7.470600  -59.516700      60.530000     56.000000       20.000000
# 50%     21.444700   27.233300      73.800000     72.000000       62.000000
# 75%     46.616600  102.500000      82.330000     84.000000       90.000000
# max     78.218600  179.316700     114.190000    100.000000      100.000000
#
#        Wind Speed (MPH)          Date
# count        557.000000  5.570000e+02
# mean           8.210952  1.627324e+09
# std            5.580634  9.203496e+01
# min            0.000000  1.627323e+09
# 25%            4.050000  1.627324e+09
# 50%            6.910000  1.627324e+09
# 75%           10.870000  1.627324e+09
# max           32.730000  1.627324e+09

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
city_data_df.plot.scatter(x="Latitude", y="Max. Temp (F)")
plt.title("City Latitude vs. Max Temperature (7/26/21)")
# Out:
# Text(0.5, 1.0, 'City Latitude vs. Max Temperature (7/26/21)')

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
city_data_df.plot.scatter(x="Latitude", y="Humidity (%)")
plt.title("City Latitude vs. Humidity (7/26/21)")
# Out:
# Text(0.5, 1.0, 'City Latitude vs. Humidity (7/26/21)')

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
city_data_df.plot.scatter(x="Latitude", y="Cloudiness (%)")
plt.title("City Latitude vs. Cloudiness (7/26/21)")
# Out:
# Text(0.5, 1.0, 'City Latitude vs. Cloudiness (7/26/21)')

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
city_data_df.plot.scatter(x="Latitude", y="Wind Speed (MPH)")
plt.title("City Latitude vs. Wind Speed (7/26/21)")
# Out:
# Text(0.5, 1.0, 'City Latitude vs. Wind Speed (7/26/21)')

# %% [markdown]
# ## Linear Regression

# %%
# Separate df into northern/southern hemisphere
north_df = city_data_df.loc[city_data_df["Latitude"] > 0]
south_df = city_data_df.loc[city_data_df["Latitude"] < 0]
# Out:
#               City  Latitude  Longitude  Max. Temp (F)  Humidity (%)  \
# 1     norman wells   65.2820  -126.8329          60.84            63
# 3      pitkyaranta   61.5734    31.4792          63.52            81
# 5        upernavik   72.7868   -56.1549          45.81            63
# 9            choix   26.7092  -108.3219          93.81            37
# 11    komsomolskiy   40.4272    71.7189          90.32            23
# ..             ...       ...        ...            ...           ...
# 552  balakhninskiy   58.0106   114.2769          57.61            71
# 553        katakwi    1.8911    33.9661          71.15            58
# 554          jizan   17.3333    42.6667          83.34            65
# 555    sainte-luce   14.4673   -60.9271          87.75            66
# 556        dauphin   51.1494  -100.0502          69.94            68
#
#      Cloudiness (%)  Wind Speed (MPH) Country        Date
# 1                75             11.50      CA  1627323638
# 3                55              3.31      RU  1627323639
# 5               100              4.59      GL  1627323639
# 9                71              4.72      MX  1627323640
# 11                0              4.61      UZ  1627323496
# ..              ...               ...     ...         ...
# 552               0              4.18      RU  1627323812
# 553             100              3.51      UG  1627323813
# 554             100              2.08      SA  1627323813
# 555              75             14.97      MQ  1627323813
# 556              40              3.44      CA  1627323546
#
# [379 rows x 9 columns]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
north_df.plot.scatter(x="Latitude", y="Max. Temp (F)")
plt.title("Northern Hemisphere City Latitude vs. Max Temperature (7/26/21)")

# Regression
# The following few lines are copy/pasted to every other plot below

# Assign x and y values to be used; find slope, intercept, rvalue, pvalue and st. dev
x_values = north_df["Latitude"]
y_values = north_df["Max. Temp (F)"]
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

# Find regression values, regression equation, and display r^2
regress_values = x_values * slope + intercept
plt.plot(x_values,regress_values,"r-")
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.annotate(line_eq,(10,40),fontsize=15,color="red")
print(f"The r-value is: {rvalue**2}")
# Out:
# The r-value is: 0.4389136902767686

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
south_df.plot.scatter(x="Latitude", y="Max. Temp (F)")
plt.title("Southern Hemisphere City Latitude vs. Max Temperature (7/26/21)")
# Regression
x_values = south_df["Latitude"]
y_values = south_df["Max. Temp (F)"]
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

regress_values = x_values * slope + intercept
plt.plot(x_values,regress_values,"r-")
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.annotate(line_eq,(-50,90),fontsize=15,color="red")
print(f"The r-value is: {rvalue**2}")
# Out:
# The r-value is: 0.5793504722530528

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
north_df.plot.scatter(x="Latitude", y="Humidity (%)")
plt.title("Northern Hemisphere City Latitude vs. Humidity (7/26/21)")

# Regression
x_values = north_df["Latitude"]
y_values = north_df["Humidity (%)"]
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

regress_values = x_values * slope + intercept
plt.plot(x_values,regress_values,"r-")
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.annotate(line_eq,(45,15),fontsize=15,color="red")
print(f"The r-value is: {rvalue**2}")
# Out:
# The r-value is: 0.010773473626156977

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
south_df.plot.scatter(x="Latitude", y="Humidity (%)")
plt.title("Southern Hemisphere City Latitude vs. Humidity (7/26/21)")

# Regression
x_values = south_df["Latitude"]
y_values = south_df["Humidity (%)"]
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

regress_values = x_values * slope + intercept
plt.plot(x_values,regress_values,"r-")
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.annotate(line_eq,(-55,15),fontsize=15,color="red")
print(f"The r-value is: {rvalue**2}")
# Out:
# The r-value is: 7.405955556719338e-05

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
north_df.plot.scatter(x="Latitude", y="Cloudiness (%)")
plt.title("Northern Hemisphere City Latitude vs. Cloudiness (7/26/21)")

# Regression
x_values = north_df["Latitude"]
y_values = north_df["Cloudiness (%)"]
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

regress_values = x_values * slope + intercept
plt.plot(x_values,regress_values,"r-")
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.annotate(line_eq,(2,5),fontsize=15,color="red")
print(f"The r-value is: {rvalue**2}")
# Out:
# The r-value is: 0.008901894237876391

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
south_df.plot.scatter(x="Latitude", y="Cloudiness (%)")
plt.title("Southern Hemisphere City Latitude vs. Cloudiness (7/26/21)")

# Regression
x_values = south_df["Latitude"]
y_values = south_df["Cloudiness (%)"]
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

regress_values = x_values * slope + intercept
plt.plot(x_values,regress_values,"r-")
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.annotate(line_eq,(-55,40),fontsize=15,color="red")
print(f"The r-value is: {rvalue**2}")
# Out:
# The r-value is: 0.013746575151318472

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
north_df.plot.scatter(x="Latitude", y="Wind Speed (MPH)")
plt.title("Northern Hemisphere City Latitude vs. Wind Speed (7/26/21)")

# Regression
x_values = north_df["Latitude"]
y_values = north_df["Wind Speed (MPH)"]
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

regress_values = x_values * slope + intercept
plt.plot(x_values,regress_values,"r-")
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.annotate(line_eq,(5,26),fontsize=15,color="red")
print(f"The r-value is: {rvalue**2}")
# Out:
# The r-value is: 0.011926263984259184

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
south_df.plot.scatter(x="Latitude", y="Wind Speed (MPH)")
plt.title("Southern Hemisphere City Latitude vs. Wind Speed (7/26/21)")

# Regression
x_values = south_df["Latitude"]
y_values = south_df["Wind Speed (MPH)"]
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

regress_values = x_values * slope + intercept
plt.plot(x_values,regress_values,"r-")
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.annotate(line_eq,(-55,23),fontsize=15,color="red")
print(f"The r-value is: {rvalue**2}")
# Out:
# The r-value is: 0.04889590094852978
